# %%
import pickle
import torch

import pandas as pd

# %%
path = '/home/users/MTrappett/mtrl/BranchGatingProject/data/hyper_search/hyper_search_results.pkl'

df = pd.read_pickle(path)

# %%
df.head()
# Out:
#    mean_accuracy   timestamp   done  training_iteration     trial_id  \
# 0       63.28125  1712960974  False                  10  0e0ff_00000
# 1       79.68750  1712960943  False                  10  0e0ff_00001
# 2       71.09375  1712960968  False                  10  0e0ff_00002
# 3       70.31250  1712960943  False                  10  0e0ff_00003
#
#                   date  time_this_iter_s  time_total_s      pid hostname  ...  \
# 0  2024-04-12_15-29-34          3.275219     32.999314  4048253  roberta  ...
# 1  2024-04-12_15-29-03          0.154893      1.669816  4048254  roberta  ...
# 2  2024-04-12_15-29-28          2.627543     26.464504  4048255  roberta  ...
# 3  2024-04-12_15-29-03          0.156837      1.697187  4048256  roberta  ...
#
#   config/model_configs/device  config/model_configs/n_npb  \
# 0                         cpu                   [56, 200]
# 1                         cpu                   [56, 200]
# ...

# %%
df[['mean_accuracy', 'config/model_name']]
# Out:
#    mean_accuracy config/model_name
# 0       63.28125       BranchModel
# 1       79.68750       ExpertModel
# 2       71.09375        MasseModel
# 3       70.31250       SimpleModel
