# %%
import pickle
import torch

from branchNetwork.plotting.plots_3_tasks import make_results_dict, plot_results

# %%
path_to_data = "/home/users/MTrappett/mtrl/BranchGatingProject/branchNetwork/data/results/rotateMnist/3task_results.pkl"

with open(path_to_data, 'rb') as f:
    data = pickle.load(f)

# %%
results_dict = make_results_dict(data)

# %%
plot_results(results_dict)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 plot_results(results_dict)
#
# File /storage/users/MTrappett/mtrl/BranchGatingProject/branchNetwork/plotting/plots_3_tasks.py:86, in plot_results(results_dictionary)
#      81 subfig_labels = ['Training Loss',
#      82                 'Validation Accuracy for Task 1',
#      83                 'Validation Accuracy for Task 2',
#      84                 'Validation Accuracy for Task 3']
#      85 results_indices = [1,5,6,7]
# ---> 86 make_plot(results_dictionary, subfig_labels, results_indices,'Comparison of evaluation accuracy after training', 'accuracy_plot', 'Accuracy')
#
# File /storage/users/MTrappett/mtrl/BranchGatingProject/branchNetwork/plotting/plots_3_tasks.py:24, in make_plot(results_dictionary, subfig_labels, results_indices, title, save_str, yaxis_label)
#      22 for j, (i, ax) in enumerate(zip(results_indices, axs)):
#      23     for results in results_dictionary.values():
# ---> 24         ax.plot(np.array(list(results.values())[i]),
#      25                 label=list(results.values())[0],
#      26                 color=colors[list(results.values())[0]],
#      27                 linewidth=2)
#      29     # Removing the red rectangle by not adding it this time
#      30     ax.grid(True)
#
# IndexError: list index out of range

# %%
from pprint import pprint

# %%
pprint(results_dict)
# Out:
# {'BranchModel': OrderedDict([('model_name', 'BranchModel'),
#                              ('Training_Loss',
#                               [0.7489146166644729,
#                                0.3974431316805676,
#                                0.6627309510287956,
#                                0.3929254847426955]),
#                              ('d0_loss',
#                               [0.4458274893403053,
#                                0.3598729076941808,
#                                0.41346384628216426,
#                                0.40147783197959264]),
#                              ('d0_Accuracy',
#                               [86.51833333333333,
#                                89.35833333333333,
#                                87.93833333333333,
#                                88.325]),
#                              ('d180_loss',
#                               [2.3383217723846434,
#                                2.3355602010091148,
#                                0.41816719466050467,
#                                0.3568658949494362]),
#                              ('d180_Accuracy',
#                               [10.923333333333334,
#                                9.566666666666666,
#                                87.155,
#                                88.925])]),
#  'ExpertModel': OrderedDict([('model_name', 'ExpertModel'),
#                              ('Training_Loss',
#                               [0.7095675533905197,
#                                0.48562463890677826,
#                                0.7054703077807213,
#                                0.5003875147836944]),
#                              ('d0_loss',
#                               [0.48079572608470916,
#                                0.40319017982681593,
#                                0.40319018019040426,
#                                0.40319018030166626]),
#                              ('d0_Accuracy',
#                               [85.59166666666667,
#                                88.05333333333333,
#                                88.05333333333333,
#                                88.05333333333333]),
#                              ('d180_loss',
#                               [2.3190198881785076,
#                                2.319019883473714,
#                                0.4204893533269564,
#                                0.3673561805307865]),
#                              ('d180_Accuracy',
#                               [5.59,
#                                5.59,
#                                87.49166666666666,
#                                89.24666666666667])]),
#  'MasseModel': OrderedDict([('model_name', 'MasseModel'),
#                             ('Training_Loss',
#                              [1.3308203334625537,
#                               0.9589252569995368,
#                               1.8288715681709802,
#                               1.3860708357046208]),
#                             ('d0_loss',
#                              [0.5505991699377696,
#                               0.5726587955554326,
#                               0.6650915968736013,
#                               0.7196891618887583]),
#                             ('d0_Accuracy',
#                              [82.88333333333334,
#                               83.93666666666667,
#                               78.825,
#                               76.85166666666667]),
#                             ('d180_loss',
#                              [3.171042896525065,
#                               3.144729776382446,
#                               0.9793473554611206,
#                               0.8159818124771118]),
#                             ('d180_Accuracy',
#                              [9.946666666666667,
#                               9.975,
#                               72.90333333333334,
#                               81.39])]),
#  'SimpleModel': OrderedDict([('model_name', 'SimpleModel'),
#                              ('Training_Loss',
#                               [0.725677139104936,
#                                0.4818705426999174,
#                                0.9112189898190026,
#                                0.5344870532520662]),
#                              ('d0_loss',
#                               [0.490685487250487,
#                                0.38144381388425824,
#                                4.580227779642741,
#                                5.04051299718221]),
#                              ('d0_Accuracy',
#                               [85.39833333333333,
#                                88.42,
#                                19.596666666666668,
#                                18.08]),
#                              ('d180_loss',
#                               [5.112037356821696,
#                                5.445843981297811,
#                                0.45282438478072484,
#                                0.33364014339844383]),
#                              ('d180_Accuracy',
#                               [9.706666666666667,
#                                15.846666666666666,
#                                86.535,
#                                90.24])])}
