# %%
import pickle
import torch

from branchNetwork.plotting.plots_3_tasks import make_results_dict, plot_results

# %%
path_to_data = "/home/users/MTrappett/mtrl/BranchGatingProject/branchNetwork/data/results/rotateMnist/3task_results.pkl"

with open(path_to_data, 'rb') as f:
    data = pickle.load(f)

# %%
results_dict = make_results_dict(data)

# %%
plot_results(results_dict)

# %%
from pprint import pprint

# %%
pprint(results_dict)
# Out:
# {'BranchModel': OrderedDict([('model_name', 'BranchModel'),
#                              ('Training_Loss',
#                               [1.26484821360713,
#                                0.49418542241326535,
#                                0.403544842351835,
#                                0.3539068103848269,
#                                0.32136685788607633,
#                                0.29553916078572645,
#                                0.2758855800450848,
#                                0.2537773784857017,
#                                0.23884677233549353,
#                                0.21969720481124264,
#                                0.20374805856490144,
#                                0.18909220305679086,
#                                0.17592373229979802,
#                                0.16290360041998161,
#                                0.14928055230525142,
#                                0.14301301178019554,
# ...
